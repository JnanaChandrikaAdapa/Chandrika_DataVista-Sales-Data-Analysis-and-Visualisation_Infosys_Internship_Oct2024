# %% [markdown]
# ## GETTING KNOW ABOUT DATASET

# %% [markdown]
# #### IMPORT LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #### IMPORT DATASET

# %%
dataset ="D:\\INTERNSHIP\\Sales-Data-Analysis-and-Visualization\\Dataset\\superstore_sales.xlsx"
sales = pd.read_excel(dataset)

# %% [markdown]
# #### DISPLAY DATASET FIRST ROWS

# %%
sales.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name    sales  \
# 0  Office Supplies      Storage          Tenex Lockers, Blue  408.300
# 1  Office Supplies     Supplies     Acme Trimmer, High Speed  120.366
# 2  Office Supplies      Storage      Tenex Box, Single Width   66.120
# 3  Office Supplies        Paper  Enermax Note Cards, Premium   44.865
# 4        Furniture  Furnishings   Eldon Light Bulb, Duo Pack  113.670
#
#    quantity  discount   profit  shipping_cost  order_priority  year
# 0         2       0.0  106.140          35.46          Medium  2011
# 1         3       0.1   36.036           9.72          Medium  2011
# 2         4       0.0   29.640           8.17            High  2011
# 3         3       0.5  -26.055           4.82            High  2011
# 4         5       0.1   37.770           4.70          Medium  2011
#
# [5 rows x 21 columns]

# %% [markdown]
# #### DISPLAY DATASET LAST ROWS

# %%
sales.tail()
# Out:
#              order_id order_date  ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427 2014-12-31 2015-01-04  Standard Class        Erica Bern
# 51286    MO-2014-2560 2014-12-31 2015-01-05  Standard Class         Liz Preis
# 51287  MX-2014-110527 2014-12-31 2015-01-02    Second Class  Charlotte Melton
# 51288  MX-2014-114783 2014-12-31 2015-01-06  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720 2014-12-31 2015-01-04  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Draâ        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# 51285  Office Supplies      Binders
# 51286  Office Supplies      Binders
# 51287  Office Supplies       Labels
# 51288  Office Supplies       Labels
# 51289  Office Supplies    Fasteners
#
#                                           product_name   sales  quantity  \
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl  13.904         2
# 51286          Wilson Jones Hole Reinforcements, Clear   3.990         1
# 51287           Hon Color Coded Labels, 5000 Label Set  26.400         3
# 51288           Hon Legal Exhibit Labels, Alphabetical   7.120         1
# 51289                              Bagged Rubber Bands   3.024         3
#
#        discount   profit  shipping_cost  order_priority  year
# 51285       0.2   4.5188          0.890          Medium  2014
# 51286       0.0   0.4200          0.490          Medium  2014
# 51287       0.0  12.3600          0.350          Medium  2014
# 51288       0.0   0.5600          0.199          Medium  2014
# 51289       0.2  -0.6048          0.170          Medium  2014
#
# [5 rows x 21 columns]

# %% [markdown]
# #### GETTING KNOW ABOUT DATSET SHAPE & COLUMNS

# %%
sales.shape
# Out:
# (51290, 21)

# %%
for columns in sales.columns:
        print(columns)
# Out:
# order_id
# order_date
# ship_date
# ship_mode
# customer_name
# segment
# state
# country
# market
# region
# product_id
# category
# sub_category
# product_name
# sales
# quantity
# discount
# profit
# shipping_cost
# order_priority
# year

# %% [markdown]
# #### GET INFORMATIONS ABOUT DATASET

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  datetime64[ns]
#  2   ship_date       51290 non-null  datetime64[ns]
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  float64
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
#  18  shipping_cost   51290 non-null  float64
#  19  order_priority  51290 non-null  object
#  20  year            51290 non-null  int64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(13)
# memory usage: 8.2+ MB

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# #### CHECK NULL VALUES

# %%
sales.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %% [markdown]
# #### GET DESCRIPTIVE STATISTICS ABOUT DATASET

# %%
sales.describe()
# Out:
#                           order_date                      ship_date  \
# count                          51290                          51290
# mean   2013-05-11 21:26:49.155780864  2013-05-15 20:42:42.745174528
# min              2011-01-01 00:00:00            2011-01-03 00:00:00
# 25%              2012-06-19 00:00:00            2012-06-23 00:00:00
# 50%              2013-07-08 00:00:00            2013-07-12 00:00:00
# 75%              2014-05-22 00:00:00            2014-05-26 00:00:00
# max              2014-12-31 00:00:00            2015-01-07 00:00:00
# std                              NaN                            NaN
#
#               sales      quantity      discount        profit  shipping_cost  \
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.490581      3.476545      0.142908     28.641740      26.375818
# min        0.444000      1.000000      0.000000  -6599.978000       0.002000
# 25%       30.758625      2.000000      0.000000      0.000000       2.610000
# 50%       85.053000      3.000000      0.000000      9.240000       7.790000
# 75%      251.053200      5.000000      0.200000     36.810000      24.450000
# max    22638.480000     14.000000      0.850000   8399.976000     933.570000
# std      487.565361      2.278766      0.212280    174.424113      57.296810
#
#                year
# count  51290.000000
# mean    2012.777208
# min     2011.000000
# 25%     2012.000000
# 50%     2013.000000
# 75%     2014.000000
# max     2014.000000
# std        1.098931

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  datetime64[ns]
#  2   ship_date       51290 non-null  datetime64[ns]
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  float64
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
#  18  shipping_cost   51290 non-null  float64
#  19  order_priority  51290 non-null  object
#  20  year            51290 non-null  int64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(13)
# memory usage: 8.2+ MB

# %% [markdown]
# #### DRIVE YEAR AND MONTH FROM 'order_date' FOR FUTURE ANALYSIS

# %%
sales['month_year'] = sales['order_date'].apply(lambda x: x.strftime('%Y-%m'))

# %%
sales['month_year'].sample(10)
# Out:
# 35084    2014-02
# 14917    2012-08
# 27626    2013-08
# 6884     2011-11
# 6556     2011-10
# 47540    2014-11
# 18800    2012-12
# 37927    2014-05
# 15420    2012-09
# 10830    2012-04
# Name: month_year, dtype: object

# %% [markdown]
# ## EXPLORATORY ANALYSIS

# %%
sales.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sub_category  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      Storage
# 3  Home Office        Stockholm     Sweden      EU    North  ...        Paper
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  Furnishings
#
#                   product_name    sales quantity  discount   profit  \
# 0          Tenex Lockers, Blue  408.300        2       0.0  106.140
# 1     Acme Trimmer, High Speed  120.366        3       0.1   36.036
# 2      Tenex Box, Single Width   66.120        4       0.0   29.640
# 3  Enermax Note Cards, Premium   44.865        3       0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack  113.670        5       0.1   37.770
#
#    shipping_cost  order_priority  year month_year
# 0          35.46          Medium  2011    2011-01
# 1           9.72          Medium  2011    2011-01
# 2           8.17            High  2011    2011-01
# 3           4.82            High  2011    2011-01
# 4           4.70          Medium  2011    2011-01
#
# [5 rows x 22 columns]

# %% [markdown]
# #### GROUP SALES BY MONTHS

# %%
# Group by 'month_year' and sum only the numeric columns
sales_by_month = sales.groupby('month_year').sum(numeric_only=True).reset_index()

# %% [markdown]
# ### VISUALIZE SALES TRAND BY MONTHS

# %%
plt.figure(figsize=(15,6))
plt.plot(sales_by_month['month_year'],sales_by_month['sales'])
plt.xticks(rotation='vertical',size=8)
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.bar(sales_by_month['month_year'],sales_by_month['sales'])
plt.xticks(rotation='vertical',size=8)
plt.show()

# %% [markdown]
# ### DISPLAY MOST SELLING PRODCUTS

# %%
products_sales = pd.DataFrame(sales.groupby('product_name')['sales'].sum())
products_sales = products_sales.sort_values('sales', ascending=False)

# %% [markdown]
# ### TOP 10 MOST SALES PRODUCTS

# %%
products_sales[:10]
# Out:
#                                                          sales
# product_name
# Apple Smart Phone, Full Size                        86935.7786
# Cisco Smart Phone, Full Size                        76441.5306
# Motorola Smart Phone, Full Size                     73156.3030
# Nokia Smart Phone, Full Size                        71904.5555
# Canon imageCLASS 2200 Advanced Copier               61599.8240
# Hon Executive Leather Armchair, Adjustable          58193.4841
# Office Star Executive Leather Armchair, Adjustable  50661.6840
# Harbour Creations Executive Leather Armchair, A...  50121.5160
# Samsung Smart Phone, Cordless                       48653.4600
# Nokia Smart Phone, with Caller ID                   47877.7857

# %%
products_by_quantity = sales.groupby('product_name')['quantity'].sum()
products_by_quantity_sorted = products_by_quantity.sort_values(ascending=False)

# %% [markdown]
# #### TOP 10 MOST QUANTITY SELLING PRODUCTS ITEMS

# %%
products_by_quantity_sorted[:10]
# Out:
# product_name
# Staples                                  876
# Cardinal Index Tab, Clear                337
# Eldon File Cart, Single Width            321
# Rogers File Cart, Single Width           262
# Sanford Pencil Sharpener, Water Color    259
# Stockwell Paper Clips, Assorted Sizes    253
# Avery Index Tab, Clear                   252
# Ibico Index Tab, Clear                   251
# Smead File Cart, Single Width            250
# Stanley Pencil Sharpener, Water Color    242
# Name: quantity, dtype: int64

# %% [markdown]
# #### VISUALIZE MOST USED SHIP MODS

# %%
plt.figure(figsize=(10,8.5))

sns.countplot(x='ship_mode', data=sales)
plt.show()

# %% [markdown]
# ### Distribution of Shiping Modes

# %%
ship_mode = pd.DataFrame(sales['ship_mode'].value_counts()).reset_index()

ship_mode = ship_mode.rename({'index': 'shiping_mode', 'ship_mode': 'count'}, axis=1)

ship_mode.head()
# Out:
#             count  count
# 0  Standard Class  30775
# 1    Second Class  10309
# 2     First Class   7505
# 3        Same Day   2701

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(ship_mode['count'], labels=ship_mode['shiping_mode'])
# show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\chand\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\chand\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\chand\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:171, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\chand\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:208, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: 'shipping_mode'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 2
#       1 fig = plt.figure(figsize =(10, 7))
# ----> 2 plt.pie(ship_mode['count'], labels=ship_mode['shipping_mode'])
#       3 # show plot
#       4 plt.show()
#
# File c:\Users\chand\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\chand\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'shipping_mode'

# %% [markdown]
# ### MOST PROFITABLE PRODUCT CATEGORIES & SUB CATEGORIES

# %%
category_by_profit = sales.groupby(['category', 'sub_category'])['profit'].sum().reset_index()

# %%
# Correct variable name
category_by_profit.sort_values(['profit'], ascending=False)
# Out:
#            category sub_category        profit
# 14       Technology      Copiers  258567.54818
# 16       Technology       Phones  216717.00580
# 0         Furniture    Bookcases  161924.41950
# 1         Furniture       Chairs  141973.79750
# 4   Office Supplies   Appliances  141680.58940
# 13       Technology  Accessories  129626.30620
# 11  Office Supplies      Storage  108461.48980
# 6   Office Supplies      Binders   72449.84600
# 10  Office Supplies        Paper   59207.68270
# 15       Technology     Machines   58867.87300
# 5   Office Supplies          Art   57953.91090
# 2         Furniture  Furnishings   46967.42550
# 7   Office Supplies    Envelopes   29601.11630
# 12  Office Supplies     Supplies   22583.26310
# 9   Office Supplies       Labels   15010.51200
# 8   Office Supplies    Fasteners   11525.42410
# 3         Furniture       Tables  -64083.38870

# %% [markdown]
# ## Top 10 Customers

# %%
sales['customer_name'].value_counts().head(10)
# Out:
# customer_name
# Muhammed Yedwab    108
# Steven Ward        106
# Patrick O'Brill    102
# Bill Eplett        102
# Gary Hwang         102
# Harry Greene       101
# Eric Murdock       100
# Art Ferguson        98
# Brosina Hoffman     97
# Bart Watters        96
# Name: count, dtype: int64

# %% [markdown]
# ### MOST SELLING SEGMENTS

# %%
plt.figure(figsize=(10,8.5))
sns.countplot(data=sales, x='segment')
plt.title('Count of Sales by Segment')  # Optional: Add a title for clarity
plt.xlabel('Segment')  # Optional: Label for the x-axis
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### SEGMENTS BY SELLING QUANTITY

# %%
# Group by 'segment' and sum only the 'quantity' column
by_segment = sales.groupby('segment')['quantity'].sum().reset_index()

# Sort the resulting DataFrame by 'quantity' in descending order
by_segment_sort = by_segment.sort_values('quantity', ascending=False)

# Display the sorted DataFrame
print(by_segment_sort)
# Out:
#        segment  quantity
# 0     Consumer     92157
# 1    Corporate     53565
# 2  Home Office     32590

# %% [markdown]
# ### SEGMENTS BY PROFIT

# %%
# Group by 'segment' and sum only the 'profit' column
by_segment_p = sales.groupby('segment')['profit'].sum().reset_index()

# Sort the resulting DataFrame by 'profit' in descending order
by_segment_sort_p = by_segment_p.sort_values('profit', ascending=False)

# Display the sorted DataFrame
print(by_segment_sort_p)
# Out:
#        segment        profit
# 0     Consumer  749239.78206
# 1    Corporate  442785.85866
# 2  Home Office  277009.18056

# %% [markdown]
# ### TOP 15 COUNTRY BY SALES

# %%
sales['country'].value_counts().head(15)
# Out:
# country
# United States         9994
# Australia             2837
# France                2827
# Mexico                2644
# Germany               2065
# China                 1880
# United Kingdom        1633
# Brazil                1599
# India                 1555
# Indonesia             1390
# Turkey                1378
# Italy                 1108
# Nigeria                905
# Spain                  859
# Dominican Republic     742
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16,9))
sns.countplot(data=sales, x='region')
plt.title('Count of Sales by Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### SUB - CATEGORIES BY SHIPING COST

# %%
# Ensure that only numeric columns are summed, ignoring non-numeric data
by_shipping_cost = sales.groupby('sub_category')['shipping_cost'].sum().reset_index()

# Sort the DataFrame by shipping cost in descending order
by_shipping_cost_sort = by_shipping_cost.sort_values('shipping_cost', ascending=False)

# Display the sorted DataFrame
by_shipping_cost_sort
# Out:
#    sub_category  shipping_cost
# 13       Phones    184902.4920
# 5        Chairs    164229.3520
# 6       Copiers    159496.2049
# 4     Bookcases    155481.9670
# 14      Storage    120546.0320
# 1    Appliances    108300.5860
# 0   Accessories     83513.3340
# 16       Tables     79861.3940
# 11     Machines     79135.8485
# 3       Binders     48181.7120
# 2           Art     41287.1420
# 9   Furnishings     40746.7660
# 12        Paper     26660.8450
# 15     Supplies     24811.5270
# 7     Envelopes     18547.4880
# 8     Fasteners      9053.3380
# 10       Labels      8059.6750

# %% [markdown]
# ### DISCOUNTS BY SUB - CATEGORIES

# %%
# Ensure that only numeric columns are summed
by_discount = sales.groupby('sub_category')['discount'].sum().reset_index()

# Sort the DataFrame by discount in descending order
by_discount_sort = by_discount.sort_values('discount', ascending=False)

# Display the sorted DataFrame
by_discount_sort
# Out:
#    sub_category  discount
# 3       Binders  1102.480
# 14      Storage   700.490
# 2           Art   573.080
# 5        Chairs   560.120
# 13       Phones   489.610
# 9   Furnishings   478.880
# 12        Paper   387.300
# 4     Bookcases   370.710
# 0   Accessories   370.480
# 8     Fasteners   340.240
# 7     Envelopes   320.810
# 10       Labels   313.890
# 15     Supplies   310.200
# 6       Copiers   260.418
# 11     Machines   252.000
# 16       Tables   250.320
# 1    Appliances   248.700

# %% [markdown]
# ### DISTRIBUTION OF DAYS TO SHIPMENT

# %%
sales['shiping_days'] = sales['ship_date']-sales['order_date']

# %%
sales.head(5)
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#                   product_name    sales quantity discount   profit  \
# 0          Tenex Lockers, Blue  408.300        2      0.0  106.140
# 1     Acme Trimmer, High Speed  120.366        3      0.1   36.036
# 2      Tenex Box, Single Width   66.120        4      0.0   29.640
# 3  Enermax Note Cards, Premium   44.865        3      0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack  113.670        5      0.1   37.770
#
#    shipping_cost  order_priority  year  month_year shiping_days
# 0          35.46          Medium  2011     2011-01       5 days
# 1           9.72          Medium  2011     2011-01       7 days
# 2           8.17            High  2011     2011-01       4 days
# 3           4.82            High  2011     2011-01       4 days
# 4           4.70          Medium  2011     2011-01       7 days
#
# [5 rows x 23 columns]

# %%
sales['shiping_days'].value_counts()
# Out:
# shiping_days
# 4 days    14434
# 5 days    11221
# 2 days     7026
# 6 days     6255
# 3 days     5035
# 7 days     3057
# 0 days     2600
# 1 days     1662
# Name: count, dtype: int64

# %% [markdown]
# ### SALES BY MARKET

# %%
sales['market'].value_counts()
# Out:
# market
# APAC      11002
# LATAM     10294
# EU        10000
# US         9994
# EMEA       5029
# Africa     4587
# Canada      384
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16, 9))
sns.countplot(x='market', data=sales)  # Use x='market' to explicitly set the x-axis
plt.xticks(rotation=45)
plt.show()
